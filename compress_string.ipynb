# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/compress_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="aabbc"
for i in range(len(a)):
  current=a[i]
  count=0

  for j in range(len(a)):
    if a[j]==current:
      count+=1
  print(current,count)
# Out:
# a 2
# a 2
# b 2
# b 2
# c 1

# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/two_sum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,3,4,5]
target=7
for i in range(len(a)):
  for j in range(i+1,len(a)):
    if a[i]+a[j]==target:
      print(a[i],a[j])
# Out:
# 3 4
# 4 3

# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/target_element_in_array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[2,3,4,5,6]
target =int(input("enter the number"))
for i in range(len(a)):
  if target==a[i]:
    print(target,i)
    break
else:
    print("nahi hai babu isme")
# Out:
# enter the number978687
# nahi hai babu isme

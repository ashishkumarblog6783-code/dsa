# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/repeated_number_n_array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=[1,1,2,3,4,4,4,5,7,8]
for i in range(len(n)-1):
 if n[i]==n[i+1]:
  print(n[i])
# Out:
# 1
# 4
# 4

# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/lonhest_substring_without_repeating_character.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="abcdabc"
freq=""
for i in range(len(a)):

  if a[i] in freq:
      break
  freq=freq+a[i]

print(len(freq))
# Out:
# 4

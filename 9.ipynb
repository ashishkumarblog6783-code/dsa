# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class solution:
  def middlenode(self,head):
    length=0
    curr=head
    while curr:
      length+=1
      curr=curr.next

    middle=length//2
    curr=head
    for _ in range(middle):
      curr=curr.next
    return curr

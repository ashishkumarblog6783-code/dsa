# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/FIND_DUPLICATE_IN_AN_ARRAY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,2,2,3,4,5,7]
for i in range(len(a)):
  count=0
  for j in range(len(a)):
    if a[i]==a[j]:
      count+=1
  if count >1:
    print(count)
# Out:
# 2
# 2

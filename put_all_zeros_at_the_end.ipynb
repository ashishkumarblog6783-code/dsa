# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/put_all_zeros_at_the_end.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,3,0,4,0,4]
result=[]
for x in a:
  if x!=0:
      result.append(x)
for x in a:
    if x==0:
      result.append(0)
print(result)
# Out:
# [1, 3, 4, 4, 0, 0]

# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/frequency_of_alphabet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="aaaple"
freq={}
for ch in a:
  if ch in freq:
    freq[ch]+=1
  else:
    freq[ch]=1
for ch in sorted(freq):
  print(ch,sorted(freq))
# Out:
# a ['a', 'e', 'l', 'p']
# e ['a', 'e', 'l', 'p']
# l ['a', 'e', 'l', 'p']
# p ['a', 'e', 'l', 'p']

# %%
heck

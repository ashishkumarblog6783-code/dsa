# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/best_time_to_buy_and_sell_the_stock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[54,86,34,90,1,4]
max_profit=0
for i in range(len(a)-1):
  for j in range(i+1,len(a)):
    profit=a[j]-a[i]
    if profit>max_profit:
      max_profit=profit
print(max_profit)
# Out:
# 56

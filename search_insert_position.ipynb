# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/search_insert_position.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[2,3,4,6,9]
target=9
left=0
right=len(a)-1
while left<=right:
  mid=(left+right)//2

  if a[mid]==target:
    print(mid)
    break
  elif a[mid]<target:
    left=mid+1
  else:
    right=mid-1
# Out:
# 4

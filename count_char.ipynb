# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/count_char.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s="applre"

for i in range(len(s)):
  count=0
  if s[i] in s[:i]:
      continue
  for j in range(len(s)):
    if s[i]==s[j]:
      count+=1

  print(s[i],count)
# Out:
# a 1
# p 2
# l 1
# r 1
# e 1

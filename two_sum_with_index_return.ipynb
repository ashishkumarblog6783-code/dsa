# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/two_sum_with_index_return.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[5,6,7,8,1,2]
target=8
for i in range(len(a)):
  for j in range(i+1,len(a)):
    if a[i]+a[j]==target:
      print(i,j,target)
# Out:
# 1 5 8
# 2 4 8

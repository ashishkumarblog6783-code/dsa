# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/check_if_parenthesis_and_bracket_are_balanced_or_not.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="[{(1,2,3,4,5)}]"
if all(b in a for b  in ('[','{','(',']','}',')')):
  print("all the brackets are present there")
else:
  print("babu ek bracketwa na haw eker mein")
# Out:
# babu ek bracketwa na haw eker mein

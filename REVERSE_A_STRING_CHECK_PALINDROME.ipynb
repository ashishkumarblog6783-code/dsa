# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/REVERSE_A_STRING_CHECK_PALINDROME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A="dam"
RESULT=A[::-1]
print(RESULT)

if A==RESULT:
  print("IT IS A PALINDROME")
else:
  print("NOT A PALINDROME")
# Out:
# mad
# NOT A PALINDROME

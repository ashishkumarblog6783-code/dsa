# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/search_a_element.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[2,3,4,5,6,10]
target=10
if target in a:
    print(f"{target} {a.index(target)}")
else:
    print(f"{target}not found")
# Out:
# 10 5

# %%
a=[2,4,5,6,7]
target=5
for i in range(len(a)):
  if target==a[i]:
    print(target,[i])
# Out:
# 5 [2]

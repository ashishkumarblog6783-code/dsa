# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/find_missing_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,2,3,4,5,7,8,9]
n=len(a)+1
exp=n*(n+1)//2
actual=sum(a)
missing=exp-actual
print(missing)
# Out:
# 6

# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/STRING_TO_INTEGER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="-123AB"
sign=1
num=0
for i in range(len(a)):
  if a[i].isdigit():
    digit=int(a[i])
    num=num*10+digit
    print(num)

  elif a[i]=="-":
    sign=-1
  else:
      break
# Out:
# 1
# 12
# 123

# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/rearrange_array_element_by_sign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[2,4,-7,-1,8,9,-2]
b=sorted(a)
for i in range(len(b)):
  for j in range(i+1,len(b)):
    if b[i]>b[j]:
      print(b[i])

# %%
a=[2,-2,-4,-6,1]
b=sorted(a)
print(b)
# Out:
# [-6, -4, -2, 1, 2]

# %%
a=[2,-2,-4,-6,1]
positive=[x for x in a if x>=0]
negative=[x for x in a if x<0]
ans =positive+negative
print(ans)
# Out:
# [2, 1, -2, -4, -6]

# %%
a=[1,-3,-6,2,7]
for i in range(len(a)):

  if i>=0:
    print(i)
  else:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

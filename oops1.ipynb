# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/oops1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Atm:
  def __init__(self):
    self.pin=""
    self.balance=0
    self.menu()

  def menu(self):
    user_input=input("""
   hello,how would u like to proceed
   1.enter 1 to create ap pin
   2.enter 2 deposit
   3.enter 3 to check balance
   4.enter 4 for withdraw
   5.enter 5 to exit

    """)
    if user_input=="1":
      self.create_pin()
    elif user_input=="2":
      self.deposit()
    elif user_input=="3":
      self.check_balance()
    elif user_input=="4":
      self.withdraw()
    else:
      print("exit")

  def create_pin(self):
    self.pin=input("enter your pin")
    print("pin set")

  def deposit(self):
    entered_pin=input("enter your pin")
    if entered_pin==self.pin:
      amount=int(input("enter amount"))
      self.balance=self.balance+amount
      print("deposit completed")
    else:
      print("invalid pin")

  def withdraw(self):
    entered_pin=input("enter your pin")
    if entered_pin==self.pin:
      amount=int(input("enter amount"))
      if amount<self.balance:
        self.balance=self.balance-amount
        print("operation done")
      else:
        print("not enough money")
    else:
      print("invalid pin")

  def check_balance(self):
    entered_pin=input("enter your pin")
    if entered_pin==self.pin:
      print(f"Your balance is: {self.balance}")
    else:
      print("invalid pin")

# %%
my_atm = Atm()
# Out:
#    hello,how would u like to proceed
#    1.enter 1 to create ap pin
#    2.enter 2 deposit
#    3.enter 3 to check balance
#    4.enter 4 for withdraw
#    5.enter 5 to exit
#
#     1
# enter your pin1234
# pin set

# %%
my_atm =Atm()
# Out:
#    hello,how would u like to proceed
#    1.enter 1 to create ap pin
#    2.enter 2 deposit
#    3.enter 3 to check balance
#    4.enter 4 for withdraw
#    5.enter 5 to exit
#
#     4
# enter your pin1234
# invalid pin

# %%
# Continue interacting with the existing my_atm object
my_atm.menu()
# Out:
#    hello,how would u like to proceed
#    1.enter 1 to create ap pin
#    2.enter 2 deposit
#    3.enter 3 to check balance
#    4.enter 4 for withdraw
#    5.enter 5 to exit
#
#     4
# enter your pin1234
# enter amount5555555
# not enough money

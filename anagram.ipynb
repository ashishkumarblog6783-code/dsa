# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/anagram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="silentg"
b="listeng"
matching_count=0
for i in range(len(a)):
  for j in range(len(b)):
    if len(a)==len(b):
      print("anagram")
    else:
        print("not a anagram")
    if a[i] == b[j]:
      print(a[i],b[j])
# Out:
# anagram
# anagram
# anagram
# s s
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# i i
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# l l
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# e e
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# n n
# anagram
# anagram
# anagram
# anagram
# anagram
# t t
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# g g

# %%
a="listen"
b="silent"
if len(a)!=len(b):
  print("not anagram")

else:
  j=sorted(a)
  k=sorted(b)
  if j==k:
    print("anagram")
  else:
    print("not a anagram")
# Out:
# anagram

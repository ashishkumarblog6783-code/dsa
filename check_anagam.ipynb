# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/check_anagam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="babu"
b="cbub"
for i in range(len(set(a))):
  for j in range(len(set(b))):
    if len(a)==len(b):
      print("anagram")
    else:
      print("not a anagram")
# Out:
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram
# anagram

# %%
a="babu"
b="abub"

if sorted(a)==sorted(b):
  print("anagram")
else:
  print("not a anagram")
# Out:
# anagram

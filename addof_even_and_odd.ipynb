# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/addof_even_and_odd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
array=[2,3,4,5,6,7,8,9]
count_odd=  [array] %%2 ==0
print count_odd
# Out:
#   File "/tmp/ipykernel_3632/300968494.py", line 2
#     count_odd= if [array] %%2 ==0
#                ^
# SyntaxError: invalid syntax

# %%
array=[3,4,5,6,7,8,9]
sum_odd=0
sum_even=0
for num in array:
  if num%2 ==0 :
    print("even",num)
    sum_odd+=num
  elif num%2 !=0:
    print("odd",num)
    sum_even+=num


    print(sum_odd,sum_even)
# Out:
# odd 3
# 0 3
# even 4
# odd 5
# 4 8
# even 6
# odd 7
# 10 15
# even 8
# odd 9
# 18 24

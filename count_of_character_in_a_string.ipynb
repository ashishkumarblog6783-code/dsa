# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/count_of_character_in_a_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="aabcdddefg"
counts={}
for i in range(len(a)):
  char=a[i]
  if char in counts:
    counts[char]+=1
  else:
    counts[char]=1
print(counts)
# Out:
# {'a': 2, 'b': 1, 'c': 1, 'd': 3, 'e': 1, 'f': 1, 'g': 1}

# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence="sai vidya institute of technology"
result=""

for char in sentence:
  if char!=" ":
    result=result+char
print(result)
# Out:
# saividyainstituteoftechnology

# %%
sentence="sai vidya institute of technology"
new=sentence.split()
print(new)
part1=new[4]
print(part1)
part2=new[2].upper()
print(part2)
part3=new[1][::-1]
print(part3)
part4=new[0].lower()
output=part1+" "+part2+" "+part3+" "+part4
print(output)
# Out:
# ['sai', 'vidya', 'institute', 'of', 'technology']
# technology
# INSTITUTE
# aydiv
# technology INSTITUTE aydiv sai

# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=input("enter input")
b=a[::-1]
if a==b:
  print("palindrome")
else:
  print("not palindrome")
# Out:
# enter inputmam
# palindrome

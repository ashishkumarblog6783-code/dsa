# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/remove_duplicate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s="apple"
count=0
for i in range(len(s)):
    if s[i] in s[:i]:
      continue

    for j in range(len(s)):
      if s[i]==s[j]:
        count=1
    print(s[i])
# Out:
# a
# p
# l
# e

# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/slidng_window.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
arr=[4,1,7,3,5]
k=3
for i in range(len(arr)-k+1):
  maximum=arr[i]
  for j in range(i,i+k):
    if arr[j]>maximum:
      maximum=arr[j]
  print(maximum)
# Out:
# 7
# 7
# 7

# %%
arr=[1,2,3,4]
k=2
for i in range(len(arr)-1):
    maximum=arr[i]
    for j in range(i,i+k):
      if arr[j]>maximum:
        maximum=arr[j]
    print(maximum)
# Out:
# 2
# 3
# 4

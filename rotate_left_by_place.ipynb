# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/rotate_left_by_place.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[4,3,2,1]
k=int(input("enter the rotations"))
for i in range(k):
  first=a[0]
  for j in range(len(a)-1):
    a[j]=a[j+1]
  a[-1]=first
print(a)
# Out:
# enter the rotations1
# [3, 2, 1, 4]

# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/buy_and_sell.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[2,5,3,8,9]
max_profit=0
for i in range(len(a)-1):
  for j in range(i+1,len(a)):
    profit=a[j]-a[i]
    if profit>max_profit:
      max_profit=profit

print(max_profit)
# Out:
# 7

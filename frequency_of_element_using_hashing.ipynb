# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/frequency_of_element_using_hashing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[2,4,4,5,6,7]

freq={}
for num in a:
  freq[num]=freq.get(num,0)+1
print(freq)
# Out:
# {2: 1, 4: 2, 5: 1, 6: 1, 7: 1}

# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/sort_array_ns_add.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,3,5,3]
b=[8,6,9,0]
x=array[a].sort()
v=array[b].sort()
m=x+v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1051/1587379435.py in <cell line: 0>()
#       1 a=[1,3,5,3]
#       2 b=[8,6,9,0]
# ----> 3 x=array[a].sort()
#       4 v=array[b].sort()
#       5 m=x+v
#
# NameError: name 'array' is not defined

# %%
a=[2,4,5,6,7]
b=[9,1,55]
result=a+b
result.sort()
print(result)
# Out:
# [1, 2, 4, 5, 6, 7, 9, 55]

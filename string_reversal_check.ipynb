# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/string_reversal_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
k = "abcd"

for i in range(len(k)):
    print(k)
    k = k[1:] + k[0]
# Out:
# abcd
# bcda
# cdab
# dabc

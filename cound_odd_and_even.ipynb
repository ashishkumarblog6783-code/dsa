# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/cound_odd_and_even.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
c=[1,2,3,4,5,6,7,8,90]
even_count=0
odd_count=0
for num in c:
  if num%2==0:
    even_count+=1
  else:
    odd_count+=1
print(even_count)
print(odd_count)
# Out:
# 5
# 4

# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/string_length.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="i am looking"
length=0
for i in range(len(a)):
  if a[i]==" ":
    continue
  length+=1
  print("length",length)
# Out:
# length 1
# length 2
# length 3
# length 4
# length 5
# length 6
# length 7
# length 8
# length 9
# length 10

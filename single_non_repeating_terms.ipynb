# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/single_non_repeating_terms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,2,2,3,3,4,4,5,5]
for i in range(len(a)):
  count=0
  for j in range(len(a)):
    if a[i]==a[j]:
      count+=1
  if count == 1:
      print(a[i])
# Out:
# 1

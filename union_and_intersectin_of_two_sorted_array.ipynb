# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/union_and_intersectin_of_two_sorted_array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,2,3,4,5]
b=[4,5,6,7,8]
#a=list(set(a))
#b=list(set(b))
c=a+b
c=list(set(c))
c.sort()
print(c)
for i in range(len(a)):
  count=0
  for j in range(len(b)):
    if a[i]== b[j]:

      print(a[i])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
# 4
# 5

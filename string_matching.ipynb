# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/string_matching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text="abcabc"
pattern="abc"

for i in range(len(text)-len(pattern)+1):
  count=0
  for j in range(len(pattern)):
    if text[i+j]==pattern[j]:
      count+=1
    if count==len(pattern):
      print(i)
# Out:
# 0
# 3

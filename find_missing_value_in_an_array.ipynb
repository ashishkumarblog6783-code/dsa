# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/find_missing_value_in_an_array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=[1,2,4,5,7,8,9]
missing=""
for  i in range(len(n)-1):
  m=n[i]+1
  if m!=n[i+1]:
    print(m)
    print(n,m)
# Out:
# 3
# [1, 2, 4, 5, 7, 8, 9] 3
# 6
# [1, 2, 4, 5, 7, 8, 9] 6

# %%
n=[1,5,6,7,8]
for i in range(len(n)-1):
  print(n[i],end=" ")
  m=n[i]+1
  while m<n[i+1]:
    print(m,end=" ")
    m+=1
print(n[-1])
# Out:
# 1 2 3 4 5 6 7 8

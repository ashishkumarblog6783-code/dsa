# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishkumarblog6783-code/dsa/blob/main/check_if_two_arrays_are_equal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,2,3,5]
b=[1,2,3,4,9]
for i in range(len(a)):
  for j in range(len(b)):
    if a[i]==b[j]:
      print("arras are equal")
# Out:
# arras are equal
# arras are equal
# arras are equal

# %%
a=[1,2,3,4]
b=[4,5,6,7]

if a==b:
  print("arrays are equal")
else:
  print("arrays are not equal")
# Out:
# arrays are not equal
